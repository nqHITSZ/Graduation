# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2 as cv

# %%
iml = cv.imread("im2.png",cv.IMREAD_GRAYSCALE)

# %%
imr = cv.imread("im6.png",cv.IMREAD_GRAYSCALE)

# %%
plt.imshow(iml)
iml.shape
# Out:
# (375, 450)

# %%
row_start = 275
col_start = 50
sl = iml[row_start:row_start+100,col_start:col_start+120]
sr = imr[row_start:row_start+100,col_start:col_start+120]
print(sl.shape)
# Out:
# (100, 120)

# %%
print("lift")
plt.figure()
plt.imshow(sl)
print("right")
plt.figure()
plt.imshow(sr)
# Out:
# lift
# right

# %%
cv.imwrite('3L.bmp',sl)
cv.imwrite('3R.bmp',sr)
# Out:
# True

# %%
sl.shape
# Out:
# (75, 120)

# %%
cv.imwrite('%dR.bmp' % 3,sr)
# Out:
# True

# %%
# %run slice_stervo.py
